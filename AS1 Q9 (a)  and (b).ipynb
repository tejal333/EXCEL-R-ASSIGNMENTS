# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Tejal/Desktop/assignment main/Q9_a.csv")

# %%
df
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
df.describe()
# Out:
#           Index      speed        dist
# count  50.00000  50.000000   50.000000
# mean   25.50000  15.400000   42.980000
# std    14.57738   5.287644   25.769377
# min     1.00000   4.000000    2.000000
# 25%    13.25000  12.000000   26.000000
# 50%    25.50000  15.000000   36.000000
# 75%    37.75000  19.000000   56.000000
# max    50.00000  25.000000  120.000000

# %%
df.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
###Question 9 (b)

# %%
import pandas as np
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea
# %matplotlib inline

# %%
ds = pd.read_csv("C:/Users/Tejal/Desktop/assignment main/Q9_b.csv")

# %%
ds
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
ds.skew()
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
ds.kurt()
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
ds.boxplot()
# Out:
# <Axes: >
